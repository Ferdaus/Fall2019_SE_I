# %%
from urllib.request import urlretrieve
import os
import math
from multiprocessing import Pool

# %%
url_files = ['../../imagenet_fall11_urls/Homo-sapiens-sapiens_modern man_n02475669.txt',
            '../../imagenet_fall11_urls/World_human-race_humanity_humankind_human-beings_humans_mankind_man_n02472987.txt']

savedirs = {
            url_files[0]:'homosapiens',
            url_files[1]:'humanrace',
           }

datasetdir = '../../Selfie_dataset/'
# save the first set as homosapiens and the second as humanrace

# %%
def segmentList(lst, seglen):
    
    segs = []
    
    for i in range(0,len(lst),seglen):
        segs.append(lst[i:i+seglen])

    return segs    

def image_dloader(urls):
    for i,url in enumerate(urls):
        _, save_fname = os.path.split(url.strip())
        try:
            urlretrieve(url, os.path.join(savedir,save_fname))
        except:
            continue
        print(f'{savedirs[fname]}: #{i} file downloading from {url}')

if __name__ == '__main__':

    for fname in url_files:
        with open(fname, 'rt') as f:
            urls = f.readlines()
            savedir = os.path.join(datasetdir, savedirs[fname])
            os.makedirs(savedir, exist_ok=True)
            
            segs = segmentList(urls[1000:], 50)
            numprocesses = len(segs)
            with Pool(numprocesses) as p:
                p.map(image_dloader,segs)
# Out:
# homosapiens: #0 file downloading from http://x6f.xanga.com/bdba1004c333354902332/w36792976.jpg
#
# homosapiens: #0 file downloading from http://farm2.static.flickr.com/1225/544004041_b08423be9f.jpg
#
# homosapiens: #0 file downloading from http://www.punkoryan.com/images/march05/Ghosts%20of%20Modern%20Man%20-%20punkoryan%20-%20250205-004.jpg
#
# homosapiens: #1 file downloading from http://farm2.static.flickr.com/1162/543903450_d9b6235bbf.jpg
#
# homosapiens: #0 file downloading from http://farm2.static.flickr.com/1178/543835950_faadee2724.jpg
#
# homosapiens: #2 file downloading from http://farm1.static.flickr.com/127/392483292_449ac05790.jpg
#
# homosapiens: #1 file downloading from http://static.flickr.com/225/501883008_4f8a55852c.jpg
#
# homosapiens: #0 file downloading from http://farm2.static.flickr.com/1015/561913295_88439d455f.jpg
#
# homosapiens: #1 file downloading from http://farm1.static.flickr.com/225/446343686_d2cde7851d.jpg
#
# homosapiens: #3 file downloading from http://farm2.static.flickr.com/1074/543884103_8e80935599.jpg
#
# homosapiens: #2 file downloading from http://farm3.static.flickr.com/2379/2244162252_319547eb25.jpg
#
# homosapiens: #1 file downloading from http://i4.photobucket.com/albums/y149/roberthoodlum/colis2.bmp
#
# homosapiens: #4 file downloading from http://farm1.static.flickr.com/186/456236556_61c26e0314.jpg
#
# homosapiens: #2 file downloading from http://farm3.static.flickr.com/2110/2110486361_8c9311c0c7.jpg
#
# homosapiens: #3 file downloading from http://farm1.static.flickr.com/88/236066314_f93f614f6c.jpg
#
# homosapiens: #5 file downloading from http://farm2.static.flickr.com/1393/910908526_c6b4f7149f.jpg
#
# homosapiens: #4 file downloading from http://farm3.static.flickr.com/2003/2168728739_ab21920c80.jpg
#
# homosapiens: #6 file downloading from http://farm2.static.flickr.com/1180/543932296_17163efd4c.jpg
#
# homosapiens: #7 file downloading from http://farm1.static.flickr.com/5/8715036_e11d4c4551.jpg
#
# homosapiens: #4 file downloading from http://farm1.static.flickr.com/172/467279875_29f169e5a6.jpg
#
# homosapiens: #4 file downloading from http://farm1.static.flickr.com/44/107527098_2b7dbaeba5.jpg
#
# homosapiens: #6 file downloading from http://farm1.static.flickr.com/227/467779419_6136152d29.jpg
#
# homosapiens: #9 file downloading from http://farm1.static.flickr.com/171/429797313_b78e1f4146.jpg
#
# homosapiens: #5 file downloading from http://farm1.static.flickr.com/68/231470427_b930038bc1.jpg
#
# homosapiens: #5 file downloading from http://farm3.static.flickr.com/2104/2228659452_0e3f366929.jpg
#
# homosapiens: #7 file downloading from http://farm1.static.flickr.com/206/493542975_b445a7988f.jpg
#
# homosapiens: #1 file downloading from http://www.normanrecords.com/images/covers/57473.jpg
#
# homosapiens: #10 file downloading from http://farm2.static.flickr.com/1152/948690340_4fa3acf42c.jpg
#
# homosapiens: #4 file downloading from http://img1.mtime.com/pi/d/2004/52/2004122216830.4118368.jpg
#
# homosapiens: #2 file downloading from http://farm3.static.flickr.com/2338/2085154794_ef635feb7a.jpg
#
# homosapiens: #8 file downloading from http://www.oxid.ru/images/covers/221837.small.jpeg
#
# homosapiens: #6 file downloading from http://www.nonfamous.com/wp/wp-content/uploads/2006/09/thebiglandme.jpg
#
# homosapiens: #11 file downloading from http://farm1.static.flickr.com/106/299004517_fbf5b6f0ab.jpg
#
# homosapiens: #5 file downloading from http://farm3.static.flickr.com/2255/2086087204_82becb313a.jpg
# homosapiens: #7 file downloading from http://farm2.static.flickr.com/1053/543910779_5b29eef9f2.jpg
#
#
# homosapiens: #9 file downloading from http://farm3.static.flickr.com/2414/2237894509_f44ebee45c.jpg
#
# homosapiens: #3 file downloading from http://farm2.static.flickr.com/1189/543980256_a6b4a6c463.jpg
#
# homosapiens: #8 file downloading from http://static.flickr.com/2259/2036854395_2362bf44fc.jpg
#
# homosapiens: #6 file downloading from http://farm2.static.flickr.com/1147/1204247477_3f02c2a073.jpg
#
# homosapiens: #7 file downloading from http://farm3.static.flickr.com/2023/2221174304_e1fc455e31.jpg
#
# homosapiens: #10 file downloading from http://farm2.static.flickr.com/1406/1455195860_929564d12e.jpg
#
# homosapiens: #9 file downloading from http://growabrain.typepad.com/photos/uncategorized/modern_man_george_carlin.jpg
#
# homosapiens: #13 file downloading from http://static.flickr.com/121/299003971_a7d11f1b49.jpg
#
# homosapiens: #7 file downloading from http://farm1.static.flickr.com/131/417853072_a308da52a9.jpg
#
# homosapiens: #8 file downloading from http://farm2.static.flickr.com/1002/543862899_b77730ebe7.jpg
#
# homosapiens: #4 file downloading from http://farm1.static.flickr.com/171/413402621_fc50c215d4.jpg
#
# homosapiens: #10 file downloading from http://farm3.static.flickr.com/2010/1565400727_5f4b5b0181.jpg
#
# homosapiens: #8 file downloading from http://farm1.static.flickr.com/79/245137324_6ece794469.jpg
#
# homosapiens: #5 file downloading from http://farm1.static.flickr.com/117/280631490_642e479467.jpg
#
# homosapiens: #9 file downloading from http://farm2.static.flickr.com/1011/1095122663_16d28d4fe8.jpg
#
# homosapiens: #12 file downloading from http://farm3.static.flickr.com/2030/1898034276_13dd2ffb61.jpg
#
# homosapiens: #7 file downloading from http://farm2.static.flickr.com/1434/1096196652_28b5f4182c.jpg
#
# homosapiens: #11 file downloading from http://farm2.static.flickr.com/1200/910906496_2145c60705.jpg
#
# homosapiens: #13 file downloading from http://farm2.static.flickr.com/1055/543841532_24f1d79201.jpg
#
# homosapiens: #10 file downloading from http://farm2.static.flickr.com/1241/543875125_e5d7f7854d.jpg
#
# homosapiens: #12 file downloading from http://farm1.static.flickr.com/145/401163782_de7cb1f8e9.jpg
#
# homosapiens: #8 file downloading from http://farm1.static.flickr.com/92/240686224_d7ec228fb7.jpg
#
# homosapiens: #11 file downloading from http://www.frontbeat.com/webdesign/skabs.jpg
#
# homosapiens: #9 file downloading from http://farm1.static.flickr.com/121/283470834_f18b49d471.jpg
#
# homosapiens: #11 file downloading from http://scottthong.files.wordpress.com/2006/10/xmefullroster.jpg
#
# homosapiens: #12 file downloading from http://farm2.static.flickr.com/1224/1461737729_6a6491e865.jpg
#
# homosapiens: #13 file downloading from http://farm2.static.flickr.com/1092/910077373_fd284f9617.jpg
#
# homosapiens: #13 file downloading from http://farm2.static.flickr.com/1035/957160871_e0afb44600.jpg
#
# homosapiens: #10 file downloading from http://photo.srebrin.com/Greece/Meteora/thumbnails/tnIMG_4047%20Modern%20greek%20man.JPG
#
# homosapiens: #13 file downloading from http://farm3.static.flickr.com/2392/2227851365_de49bcb789.jpg
#
# homosapiens: #15 file downloading from http://farm3.static.flickr.com/2340/1680396611_21a2c9205a.jpg
#
# homosapiens: #14 file downloading from http://farm1.static.flickr.com/29/55998611_c9570f857d.jpg
#
# homosapiens: #14 file downloading from http://farm1.static.flickr.com/60/187229535_73c07005e7.jpg
#
# homosapiens: #14 file downloading from http://farm1.static.flickr.com/116/299942697_1fbb165031.jpg
#
# homosapiens: #16 file downloading from http://static.flickr.com/29/63713875_0721b1f733.jpg
#
# homosapiens: #11 file downloading from http://farm2.static.flickr.com/1278/674973124_5de378ec97.jpg
#
# homosapiens: #15 file downloading from http://farm1.static.flickr.com/173/414887082_d48a065042.jpg
#
# homosapiens: #16 file downloading from http://farm2.static.flickr.com/1139/765275988_7093b68209.jpg
#
# homosapiens: #17 file downloading from http://farm3.static.flickr.com/2343/1561059800_2174015929.jpg
#
# homosapiens: #15 file downloading from http://www.liceus.com/cgi-bin/gui/04/albert-camus_fumando.jpg
#
# homosapiens: #18 file downloading from http://www.limeliters.com/Picture%20099.jpg
#
# homosapiens: #18 file downloading from http://farm2.static.flickr.com/1419/839476803_5ec7480e8f.jpg
#
# homosapiens: #16 file downloading from http://static.flickr.com/1293/898383121_1cd7e88962.jpg
#
# homosapiens: #19 file downloading from http://farm3.static.flickr.com/2328/2134314859_7a3c0bc140.jpg
#
# homosapiens: #17 file downloading from http://farm2.static.flickr.com/1366/543900204_4abfde94b9.jpg
#
# homosapiens: #19 file downloading from http://farm1.static.flickr.com/171/421150143_054169a04c.jpg
#
# homosapiens: #20 file downloading from http://www.indielondon.co.uk/img/modern_man.gif
#
# homosapiens: #17 file downloading from http://farm1.static.flickr.com/40/77538373_89dcb432c4.jpg
#
# homosapiens: #13 file downloading from http://www.aidastudio.com/GRP_Photography/images/BWseries_modernman03_s.jpg
#
# homosapiens: #21 file downloading from http://farm1.static.flickr.com/93/227674729_d32c43efbd.jpg
#
# homosapiens: #22 file downloading from http://farm3.static.flickr.com/2150/1860115915_93cd22e822.jpg
#
# homosapiens: #14 file downloading from http://www.rocktheblock.co.uk/PICT0002.JPG
#
# homosapiens: #21 file downloading from http://www.leeirving.com/images/Scroogeforthemodernman.jpg
#
# homosapiens: #23 file downloading from http://farm2.static.flickr.com/1363/1400627544_ede12307a0.jpg
#
# homosapiens: #22 file downloading from http://farm3.static.flickr.com/2356/1861239418_37272c29be.jpg
#
# homosapiens: #24 file downloading from http://farm1.static.flickr.com/135/384371767_d58b2186b2.jpg
#
# homosapiens: #16 file downloading from http://farm2.static.flickr.com/1186/735360118_70ebf971bc.jpg
#
# homosapiens: #26 file downloading from http://farm1.static.flickr.com/216/502331761_42e30e90d8.jpg
#
# homosapiens: #17 file downloading from http://farm1.static.flickr.com/152/348076556_5bc134365d.jpg
#
# homosapiens: #15 file downloading from http://www.cartype.com/images/page/radebaugh_artist_easel.jpg
#
# homosapiens: #21 file downloading from http://farm1.static.flickr.com/227/456236908_156609acd7.jpg
#
# homosapiens: #27 file downloading from http://farm3.static.flickr.com/2202/2095053611_d1bcdfacac.jpg
#
# homosapiens: #18 file downloading from http://static.flickr.com/2393/2027211543_5778c4377f.jpg
#
# homosapiens: #28 file downloading from http://farm1.static.flickr.com/48/185156077_bb715edf76.jpg
#
# homosapiens: #22 file downloading from http://farm2.static.flickr.com/1235/910056849_5832b4a398.jpg
#
# homosapiens: #20 file downloading from http://farm3.static.flickr.com/2019/1675993696_7471429f59.jpg
#
# homosapiens: #19 file downloading from http://farm2.static.flickr.com/1129/921715782_7e573986db.jpg
#
# homosapiens: #29 file downloading from http://farm1.static.flickr.com/192/456251065_2419e89c89.jpg
#
# homosapiens: #23 file downloading from http://farm2.static.flickr.com/1440/543852553_d60a05cfff.jpg
#
# homosapiens: #21 file downloading from http://farm1.static.flickr.com/191/501897717_3b923bbda6.jpg
#
# homosapiens: #24 file downloading from http://farm3.static.flickr.com/2252/2225809683_ac8d0a906f.jpg
#
# homosapiens: #16 file downloading from http://www.coleyandcoleyeyecare.com/Nov05%20images/man.jpg
#
# homosapiens: #20 file downloading from http://farm3.static.flickr.com/2075/2043864996_9404fb478e.jpg
#
# homosapiens: #25 file downloading from http://static.flickr.com/181/414355937_66d8161758.jpg
#
# homosapiens: #23 file downloading from http://farm1.static.flickr.com/226/456360670_6dda333b5f.jpg
#
# homosapiens: #24 file downloading from http://farm1.static.flickr.com/64/188455167_7ce2c06217.jpg
#
# homosapiens: #17 file downloading from http://www.abruanbd.com/product/man-07.jpg
#
# homosapiens: #18 file downloading from http://static.flickr.com/2018/1495482525_b104c204a0.jpg
#
# homosapiens: #25 file downloading from http://farm1.static.flickr.com/210/473087029_5cac6e8ef4.jpg
#
# homosapiens: #28 file downloading from http://farm1.static.flickr.com/173/456236678_da3c58c89d.jpg
#
# homosapiens: #19 file downloading from http://farm3.static.flickr.com/2003/1562581391_7a90fc4dfd.jpg
#
# homosapiens: #26 file downloading from http://farm1.static.flickr.com/247/524759728_c17df8c795.jpg
#
# homosapiens: #29 file downloading from http://farm3.static.flickr.com/2067/2108324534_138e239c23.jpg
#
# homosapiens: #32 file downloading from http://static.flickr.com/94/205987875_24c9e69528.jpg
#
# homosapiens: #30 file downloading from http://farm1.static.flickr.com/228/502304303_748159c033.jpg
#
# homosapiens: #20 file downloading from http://static.flickr.com/1314/898383141_37c9a28570.jpg
#
# homosapiens: #21 file downloading from http://www.yourcreditnetwork.com/images/blog/do-not-eat-your-credit-card.jpg
#
# homosapiens: #33 file downloading from http://farm1.static.flickr.com/43/84154727_a7a47a03ef.jpg
#
# homosapiens: #31 file downloading from http://www.nonfamous.com/wp/wp-content/uploads/2006/09/biglquake.jpg
#
# homosapiens: #28 file downloading from http://www.featurepics.com/FI/Thumb/20061211/Man-modern-building-163634.jpg
#
# homosapiens: #22 file downloading from http://farm2.static.flickr.com/1346/573758593_25848a3f2b.jpg
#
# homosapiens: #25 file downloading from http://farm2.static.flickr.com/1291/543812952_c5f1ce8fb3.jpg
#
# homosapiens: #29 file downloading from http://farm3.static.flickr.com/2359/1860931942_40b770463d.jpg
#
# homosapiens: #34 file downloading from http://farm3.static.flickr.com/2133/2118600150_1c104245c7.jpg
#
# homosapiens: #23 file downloading from http://farm1.static.flickr.com/147/348079768_894ad4d26c.jpg
#
# homosapiens: #30 file downloading from http://static.flickr.com/107/255194469_8e06a4ffd6.jpg
#
# homosapiens: #26 file downloading from http://farm1.static.flickr.com/51/109772007_4ae98cf82c.jpg
#
# homosapiens: #35 file downloading from http://farm1.static.flickr.com/168/456236618_7a43f0e14d.jpg
#
# homosapiens: #31 file downloading from http://static.flickr.com/217/456236694_493424b03b.jpg
#
# homosapiens: #36 file downloading from http://farm2.static.flickr.com/1291/712698808_28fe4a57b8.jpg
#
# homosapiens: #24 file downloading from http://farm1.static.flickr.com/232/452254290_ff1a0c9a21.jpg
#
# homosapiens: #32 file downloading from http://www.emusic.com/img/album/108/590/10859024_155_155.jpeg
#
# homosapiens: #39 file downloading from http://farm1.static.flickr.com/157/351708313_ce08482b84.jpg
#
# homosapiens: #33 file downloading from http://farm1.static.flickr.com/81/206355577_570ce9c374.jpg
#
# homosapiens: #25 file downloading from http://farm3.static.flickr.com/2355/2007756565_0fcedc511a.jpg
#
# homosapiens: #28 file downloading from http://www.foreignsoulmate.com/images/p75792-1.jpg
#
# homosapiens: #40 file downloading from http://farm3.static.flickr.com/2001/1860421213_f9af8c8506.jpg
#
# homosapiens: #29 file downloading from http://farm1.static.flickr.com/11/13979374_678b4d8c28.jpg
# homosapiens: #34 file downloading from http://farm3.static.flickr.com/2401/2170428623_3af5fa22ea.jpg
#
#
# homosapiens: #41 file downloading from http://farm1.static.flickr.com/109/295408484_516cd9c121.jpg
#
# homosapiens: #26 file downloading from http://farm3.static.flickr.com/2349/1561936718_6507d867cd.jpg
#
# homosapiens: #30 file downloading from http://farm1.static.flickr.com/55/176485592_85715497ed.jpg
#
# homosapiens: #27 file downloading from http://static.flickr.com/225/501886098_112a591a07.jpg
#
# homosapiens: #42 file downloading from http://farm2.static.flickr.com/1006/710329762_59ca765066.jpg
#
# homosapiens: #36 file downloading from http://farm1.static.flickr.com/230/501931097_46a13cf135.jpg
#
# homosapiens: #31 file downloading from http://farm1.static.flickr.com/63/160968136_dff10aa98b.jpg
#
# homosapiens: #43 file downloading from http://farm2.static.flickr.com/1217/1114224270_5e75b180bf.jpg
#
# homosapiens: #37 file downloading from http://farm1.static.flickr.com/205/456237082_d1042a4003.jpg
#
# homosapiens: #32 file downloading from http://farm2.static.flickr.com/1409/910060305_bac6bca2b7.jpg
#
# homosapiens: #28 file downloading from http://farm2.static.flickr.com/1114/1353186773_916597452b.jpg
#
# homosapiens: #38 file downloading from http://farm1.static.flickr.com/21/29749458_dd20392780.jpg
#
# homosapiens: #29 file downloading from http://farm3.static.flickr.com/2338/1634543046_86dc23a4b5.jpg
#
# homosapiens: #44 file downloading from http://www001.upp.so-net.ne.jp/gako-oku/Modern.files/Schneiderman2.jpg
#
# homosapiens: #39 file downloading from http://farm3.static.flickr.com/2121/2226450647_0c3191f1fd.jpg
#
# homosapiens: #45 file downloading from http://farm1.static.flickr.com/165/338337790_1928b48859.jpg
#
# homosapiens: #40 file downloading from http://farm2.static.flickr.com/1083/543846405_33c0510f39.jpg
#
# homosapiens: #41 file downloading from http://farm3.static.flickr.com/2206/1562583943_72f290bc93.jpg
#
# homosapiens: #34 file downloading from http://www.museum.upenn.edu/Mongolia/images/2.17.jpg
#
# homosapiens: #42 file downloading from http://farm1.static.flickr.com/102/283927280_ae3267835d.jpg
# homosapiens: #46 file downloading from http://farm3.static.flickr.com/2073/2247231292_bfdfd44066.jpg
#
#
# homosapiens: #47 file downloading from http://www.cgstock.com/pics/4918.jpg
#
# homosapiens: #48 file downloading from http://farm2.static.flickr.com/1091/1462569214_2ddfb42c6d.jpg
#
# homosapiens: #30 file downloading from http://www.cult-cinema.ru/pictures/screenshots/the_wicker_man/the_wicker_man7.jpg
#
# homosapiens: #43 file downloading from http://farm2.static.flickr.com/1141/898886535_f592cef864.jpg
#
# homosapiens: #35 file downloading from http://farm1.static.flickr.com/84/264055268_67885fd236.jpg
#
# homosapiens: #49 file downloading from http://static.flickr.com/140/348072670_f5affb44f1.jpg
#
# homosapiens: #31 file downloading from http://farm1.static.flickr.com/181/456237036_c84e78eb00.jpg
#
# homosapiens: #44 file downloading from http://farm1.static.flickr.com/114/299004116_cc38c72999.jpg
#
# homosapiens: #36 file downloading from http://farm3.static.flickr.com/2188/1568856726_f17f021c41.jpg
#
# homosapiens: #37 file downloading from http://static.flickr.com/2202/1947387480_8285378056.jpg
#
# homosapiens: #38 file downloading from http://farm3.static.flickr.com/2023/2199848713_6db207c185.jpg
#
# homosapiens: #39 file downloading from http://farm3.static.flickr.com/2219/1909062770_8e02d209c6.jpg
#
# homosapiens: #40 file downloading from http://farm3.static.flickr.com/2186/2168728119_9c28ae9254.jpg
#
# homosapiens: #41 file downloading from http://farm1.static.flickr.com/188/470971090_054df7abd9.jpg
#
# homosapiens: #33 file downloading from http://www.libreriaeditriceurso.com/avolainlaboratorio/presocratici1.jpg
#
# homosapiens: #42 file downloading from http://farm3.static.flickr.com/2109/1561934234_35ac440d6d.jpg
#
# homosapiens: #44 file downloading from http://farm3.static.flickr.com/2067/1566640809_646e90c57d.jpg
#
# homosapiens: #34 file downloading from http://boink.noblogs.org/gallery/296/previews-med/prec2.jpg
#
# homosapiens: #47 file downloading from http://farm1.static.flickr.com/184/430975576_8ba6539cae.jpg
#
# homosapiens: #48 file downloading from http://static.flickr.com/219/502283354_e1a4274254.jpg
#
# homosapiens: #49 file downloading from http://farm3.static.flickr.com/2159/1563274831_a8c789a0fc.jpg
#
# homosapiens: #33 file downloading from http://farm2.static.flickr.com/1386/543771554_4d77b4a6db.jpg
#
# homosapiens: #35 file downloading from http://farm2.static.flickr.com/1334/1084829967_fe4f019982.jpg
#
# homosapiens: #36 file downloading from http://farm1.static.flickr.com/85/270512045_37fc2c2c73.jpg
#
# homosapiens: #37 file downloading from http://www.samizdata.net/~pdeh/exquisite_redcaps_in_iraq_medium.jpg
#
# homosapiens: #38 file downloading from http://farm1.static.flickr.com/70/169385063_444814722d.jpg
#
# homosapiens: #39 file downloading from http://farm3.static.flickr.com/2309/2085163086_f6c04268cc.jpg
#
# homosapiens: #40 file downloading from http://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Tochiazuma_Daisuke.jpg/180px-Tochiazuma_Daisuke.jpg
#
# homosapiens: #41 file downloading from http://farm2.static.flickr.com/1290/543889970_903fb30ee2.jpg
#
# homosapiens: #42 file downloading from http://farm1.static.flickr.com/56/158802618_8fd02c4905.jpg
#
# homosapiens: #43 file downloading from http://farm1.static.flickr.com/163/348080352_a086012831.jpg
#
# homosapiens: #44 file downloading from http://farm3.static.flickr.com/2252/1561060198_e4645ab603.jpg
#
# homosapiens: #45 file downloading from http://farm3.static.flickr.com/2036/2222174996_c51c867365.jpg
#
# homosapiens: #46 file downloading from http://farm2.static.flickr.com/1417/543938117_a6fff91cba.jpg
#
# homosapiens: #48 file downloading from http://farm1.static.flickr.com/61/161751815_bb42b1979a.jpg
#
# homosapiens: #49 file downloading from http://farm2.static.flickr.com/1298/1398829872_70989a837c.jpg
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-36:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/tarik/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-781b4a175d95> in <module>()
#      28             numprocesses = len(segs)
#      29             with Pool(numprocesses) as p:
# ---> 30                 p.map(image_dloader,segs)
#      31
#      32
#
# ~/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/envs/project_selfie/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/envs/project_selfie/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/project_selfie/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
# Out:
#  fall11_urls.txt
# 'Homo-sapiens-sapiens_modern man_n02475669.txt'
#  World_human-race_humanity_humankind_human-beings_humans_mankind_man_n02472987.txt
