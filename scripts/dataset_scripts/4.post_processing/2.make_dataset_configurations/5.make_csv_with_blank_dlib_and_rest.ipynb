# %%
import pandas as pd
import pathlib
import numpy as np
import os

import time
import cv2
from matplotlib import pyplot as plt

# %%
# im_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/raw_image/'
# skel_im_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/color_skeleton/im+skeleton/'
# skel_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/color_skeleton/skeleton/'

# im_dlib_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/dlib_images/im+dlib/'
# im_skel_dlib_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/dlib_images/im+skel+dlib/'
# skel_dlib_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/dlib_images/skel+dlib/'

#im_new_name = im_dlib_base_path+class_name+'/' + fname.replace('.jpg','_dlib.jpg')

#skel_dlib_new_name = skel_dlib_base_path+class_name+'/' + skeleton_fname.replace('_skeleton.jpg','_skeleton_dlib.jpg')

#im_skel_dlib_new_name = im_skel_dlib_base_path+class_name+'/' + im_skeleton_fname.replace('_im_skeleton.jpg','_im_skeleton_dlib.jpg')

#im_skel_dlib_new_name = im_skel_dlib_base_path+class_name+'/' + im_skeleton_fname.replace('_im_skeleton.jpg','_im_skeleton_dlib.jpg')

#blank_im_new_name = dlib_base_path + class_name + '/' + fname.replace('.jpg','_dlib_only.jpg')

ims_ypr_dlib_csv_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/dlib_faces/'

save_csv_base_path = '/disks/data/paper_projects/selfie_detection/data/DS_224_all_features_no_duplicates/CSVs/im_skel_im-skel_mask_dlib-images_ypr_dlib_pts/'

# %%
class_names = ['mirror_selfie','non_mirror_selfie','non_selfie','selfie']

# %%
class_name = class_names[3]

# %%
ims_ypr_dlib = pd.read_csv(ims_ypr_dlib_csv_base_path+class_name+'.csv')

# %%
ims_ypr_dlib.head()
# Out:
#                                    im_name       x_min       y_min  \
# 0     google_selfie_face_170616_000001.jpg   69.812607    4.751129
# 1                 selfie_mshah_0001648.jpg   53.091011   12.870911
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg  148.288559  124.413925
# 3                 selfie_mshah_0018411.jpg   33.179024   63.901459
# 4                 selfie_mshah_0018349.jpg  110.925224   29.970924
#
#         x_max       y_max  confidence_score       yaw      pitch       roll  \
# 0  162.124390  135.267654               NaN -9.648262  -3.431259  -6.078819
# 1  208.733215  216.841751               NaN -0.098442  -7.082375 -13.808197
# 2  210.506119  214.626694               NaN  8.638893   4.630257  -3.675873
# 3  154.551422  237.846588               NaN -3.005219 -15.897232   0.924484
# 4  243.742859  227.320526               NaN -1.087578   0.386696 -13.165344
#
#    left  ...  y_65  x_66  y_66  x_67  y_67  x_68  y_68  \
# 0    46  ...    76    98    79    96    79    92    80
# 1    38  ...   117   115   129   108   132   101   133
# 2   106  ...   141   136   140   134   140   131   140
# 3    26  ...   142    79   148    74   149    68   148
# 4    79  ...   130   145   134   140   135   135   135
#
#                                             skeleton  \
# 0  google_selfie_face_170616_000001.jpg_skeleton.jpg
# 1              selfie_mshah_0001648.jpg_skeleton.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_skelet...
# 3              selfie_mshah_0018411.jpg_skeleton.jpg
# 4              selfie_mshah_0018349.jpg_skeleton.jpg
#
#                                          im_skeleton  \
# 0  google_selfie_face_170616_000001.jpg_im_skelet...
# 1           selfie_mshah_0001648.jpg_im_skeleton.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_im_ske...
# 3           selfie_mshah_0018411.jpg_im_skeleton.jpg
# 4           selfie_mshah_0018349.jpg_im_skeleton.jpg
#
#                                            im_masked
# 0    google_selfie_face_170616_000001.jpg_masked.jpg
# 1                selfie_mshah_0001648.jpg_masked.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_masked...
# 3                selfie_mshah_0018411.jpg_masked.jpg
# 4                selfie_mshah_0018349.jpg_masked.jpg
#
# [5 rows x 152 columns]

# %%
ims_ypr_dlib['dlib'] = ims_ypr_dlib.im_name.replace('.jpg','_dlib_only.jpg', inplace = False, regex = True)

# %%
ims_ypr_dlib['im_dlib'] = ims_ypr_dlib.im_name.replace('.jpg','_dlib.jpg', inplace = False, regex = True)

# %%
ims_ypr_dlib['skel_dlib'] = ims_ypr_dlib.skeleton.replace('_skeleton.jpg','_skeleton_dlib.jpg', inplace = False, regex = True)

# %%
ims_ypr_dlib['im_skel_dlib'] = ims_ypr_dlib.im_skeleton.replace('_im_skeleton.jpg','_im_skeleton_dlib.jpg', inplace = False, regex = True)

# %%
ims_ypr_dlib.head()
# Out:
#                                    im_name       x_min       y_min  \
# 0     google_selfie_face_170616_000001.jpg   69.812607    4.751129
# 1                 selfie_mshah_0001648.jpg   53.091011   12.870911
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg  148.288559  124.413925
# 3                 selfie_mshah_0018411.jpg   33.179024   63.901459
# 4                 selfie_mshah_0018349.jpg  110.925224   29.970924
#
#         x_max       y_max  confidence_score       yaw      pitch       roll  \
# 0  162.124390  135.267654               NaN -9.648262  -3.431259  -6.078819
# 1  208.733215  216.841751               NaN -0.098442  -7.082375 -13.808197
# 2  210.506119  214.626694               NaN  8.638893   4.630257  -3.675873
# 3  154.551422  237.846588               NaN -3.005219 -15.897232   0.924484
# 4  243.742859  227.320526               NaN -1.087578   0.386696 -13.165344
#
#    left  ...  y_67  x_68  y_68  \
# 0    46  ...    79    92    80
# 1    38  ...   132   101   133
# 2   106  ...   140   131   140
# 3    26  ...   149    68   148
# 4    79  ...   135   135   135
#
#                                             skeleton  \
# 0  google_selfie_face_170616_000001.jpg_skeleton.jpg
# 1              selfie_mshah_0001648.jpg_skeleton.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_skelet...
# 3              selfie_mshah_0018411.jpg_skeleton.jpg
# 4              selfie_mshah_0018349.jpg_skeleton.jpg
#
#                                          im_skeleton  \
# 0  google_selfie_face_170616_000001.jpg_im_skelet...
# 1           selfie_mshah_0001648.jpg_im_skeleton.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_im_ske...
# 3           selfie_mshah_0018411.jpg_im_skeleton.jpg
# 4           selfie_mshah_0018349.jpg_im_skeleton.jpg
#
#                                            im_masked  \
# 0    google_selfie_face_170616_000001.jpg_masked.jpg
# 1                selfie_mshah_0001648.jpg_masked.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_masked...
# 3                selfie_mshah_0018411.jpg_masked.jpg
# 4                selfie_mshah_0018349.jpg_masked.jpg
#
#                                                 dlib  \
# 0     google_selfie_face_170616_000001_dlib_only.jpg
# 1                 selfie_mshah_0001648_dlib_only.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c_dlib_only.jpg
# 3                 selfie_mshah_0018411_dlib_only.jpg
# 4                 selfie_mshah_0018349_dlib_only.jpg
#
#                                         im_dlib  \
# 0     google_selfie_face_170616_000001_dlib.jpg
# 1                 selfie_mshah_0001648_dlib.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c_dlib.jpg
# 3                 selfie_mshah_0018411_dlib.jpg
# 4                 selfie_mshah_0018349_dlib.jpg
#
#                                            skel_dlib  \
# 0  google_selfie_face_170616_000001.jpg_skeleton_...
# 1         selfie_mshah_0001648.jpg_skeleton_dlib.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_skelet...
# 3         selfie_mshah_0018411.jpg_skeleton_dlib.jpg
# 4         selfie_mshah_0018349.jpg_skeleton_dlib.jpg
#
#                                         im_skel_dlib
# 0  google_selfie_face_170616_000001.jpg_im_skelet...
# 1      selfie_mshah_0001648.jpg_im_skeleton_dlib.jpg
# 2  selfie_tag_22327052554_d12e2c56bc_c.jpg_im_ske...
# 3      selfie_mshah_0018411.jpg_im_skeleton_dlib.jpg
# 4      selfie_mshah_0018349.jpg_im_skeleton_dlib.jpg
#
# [5 rows x 156 columns]

# %%
ims_ypr_dlib.to_csv(save_csv_base_path+f'{class_name}.csv',
                              columns = ims_ypr_dlib.columns, 
                              header = ims_ypr_dlib.columns,
                              index = False)
