# %%
from fastai import *

# %%
from fastai.vision import *
from fastai.widgets import *

# %%
ds_path = '/disks/data/paper_projects/selfie_detection/data/DS_merged'

# %%
# create a databunch from the images; no validation images
db = (ImageList.from_folder(ds_path).split_none()
                   .label_from_folder().transform(size=224)
                   .databunch())

# %%
# define a cnn
learn = cnn_learner(db, models.resnet50, metrics=error_rate)

# %%
# detect similar images
ds, idxs = DatasetFormatter().from_similars(learn, layer_ls=[0,7,1], pool=None)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='56' class='' max='56', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [56/56 00:10<00:00]
#     </div>
# Computing similarities...

# %% [markdown]
# ## view the duplicates

# %%
from matplotlib import pyplot as plt

# view the duplicate images
for i in range(0, len(idxs), 2):
    
    path1 = ds.x.items[idxs[i]]
    path2 = ds.x.items[idxs[i+1]]
    im1 = plt.imread(path1)
    im2 = plt.imread(path2)
    plt.Figure(figsize=(40,15))
    plt.subplot(121)
    plt.imshow(im1)
    print(path1)    
    plt.subplot(122)
    plt.imshow(im2)
    print(path2)
    plt.show()
    input("Press Enter to continue...")
# Out:
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/portrait-gallery_30942008276_de7930eac8_c.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/30942008276_de7930eac8_c.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastyear_000317.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastmonth_000300.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_photo_091218_000228.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_face_091218_000118.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/1548708971_e2079aa991.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/imagenet_humanrace_1548708971_e2079aa991.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000164.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_face_091218_000040.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_long_shot_photo_091218_000156.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_shot_pastyear_000035.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000020.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_long_shot_photo_091218_000156.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000020.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_shot_pastyear_000035.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_shot_pastmonth_000047.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_close_up_pastmonth_000090.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_close_up_pastyear_000133.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_close_up_pastmonth_000068.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastmonth_000063.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastweek_000012.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_face_091218_000131.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000254.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/1474956331_9b0d34b19c.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/imagenet_humanrace_1474956331_9b0d34b19c.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_face_091218_000203.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_photo_091218_000091.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_face_091218_000563.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_photo_091218_000244.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_shot_pastyear_000166.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_long_shot_pastyear_000317.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/imagenet_humanrace_127856539_9e4e8cae7d.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/127856539_9e4e8cae7d.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastyear_000166.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastmonth_000136.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_photo_091218_000538.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_faces_face_091218_000477.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_face_091218_000206.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000086.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up__091218_000123.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/google_medium_close_up_photo_091218_000075.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastyear_000475.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastmonth_000449.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_close_up_pastyear_000170.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/non_selfie__confirmed/bing_medium_long_shot_pastyear_000069.jpg
# Press Enter to continue...
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastyear_000064.jpg
# /disks/data/paper_projects/selfie_detection/data/DS_merged/selfie__confirmed/bing_selfie_pastmonth_000006.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3d8c93eddc50> in <module>
#      16     print(path2)
#      17     plt.show()
# ---> 18     input("Press Enter to continue...")
#      19
#      20
#
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ## move duplicates to another folder keeping class structure intact

# %%
import os

# moves the duplicates in a directory parallel to the image class folders in the dataset directory

last_dir_ds_path = ds_path[ds_path.rfind('/')+1:]
trash_path = 'duplicates'

[os.makedirs(ds_path.replace(last_dir_ds_path, last_dir_ds_path+'/'+trash_path+'/'+im_class), exist_ok= True) for im_class in ds.classes]

dups = list(set([ds.x.items[idxs[i]] for i in range(0, len(idxs),2)]))


for fname in dups:
    os.rename(str(fname), str(fname).replace(last_dir_ds_path+'/', last_dir_ds_path+'/'+trash_path+'/'))

# %%
# ImageCleaner(ds, idxs, ds_path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
[print(im_class) for im_class in ds.classes]
# Out:
# non_selfie__confirmed
# selfie__confirmed
# [None, None]

# %%
# Out:
# '/DS_merged'

# %%
DatasetFormatter??
# Out:
# Init signature: DatasetFormatter()
# Source:
# class DatasetFormatter():
#     "Returns a dataset with the appropriate format and file indices to be displayed."
#     @classmethod
#     def from_toplosses(cls, learn, n_imgs=None, **kwargs):
#         "Gets indices with top losses."
#         train_ds, train_idxs = cls.get_toplosses_idxs(learn, n_imgs, **kwargs)
#         return train_ds, train_idxs
#
#     @classmethod
#     def get_toplosses_idxs(cls, learn, n_imgs, **kwargs):
#         "Sorts `ds_type` dataset by top losses and returns dataset and sorted indices."
#         dl = learn.data.fix_dl
#         if not n_imgs: n_imgs = len(dl.dataset)
#         _,_,top_losses = learn.get_preds(ds_type=DatasetType.Fix, with_loss=True)
#         idxs = torch.topk(top_losses, n_imgs)[1]
#         return cls.padded_ds(dl.dataset, **kwargs), idxs
#
#     def padded_ds(ll_input, size=(250, 300), resize_method=ResizeMethod.CROP, padding_mode='zeros', **kwargs):
#         "For a LabelList `ll_input`, resize each image to `size` using `resize_method` and `padding_mode`."
#         return ll_input.transform(tfms=crop_pad(), size=size, resize_method=resize_method, padding_mode=padding_mode)
#
#     @classmethod
#     def from_similars(cls, learn, layer_ls:list=[0, 7, 2], **kwargs):
#         "Gets the indices for the most similar images."
#         train_ds, train_idxs = cls.get_similars_idxs(learn, layer_ls, **kwargs)
#         return train_ds, train_idxs
#
#     @classmethod
#     def get_similars_idxs(cls, learn, layer_ls, **kwargs):
#         "Gets the indices for the most similar images in `ds_type` dataset"
#         hook = hook_output(learn.model[layer_ls[0]][layer_ls[1]][layer_ls[2]])
#         dl = learn.data.fix_dl
#
#         ds_actns = cls.get_actns(learn, hook=hook, dl=dl, **kwargs)
#         similarities = cls.comb_similarity(ds_actns, ds_actns, **kwargs)
#         idxs = cls.sort_idxs(similarities)
#         return cls.padded_ds(dl, **kwargs), idxs
#
#     @staticmethod
#     def get_actns(learn, hook:Hook, dl:DataLoader, pool=AdaptiveConcatPool2d, pool_dim:int=4, **kwargs):
#         "Gets activations at the layer specified by `hook`, applies `pool` of dim `pool_dim` and concatenates"
#         print('Getting activations...')
#
#         actns = []
#         learn.model.eval()
#         with torch.no_grad():
#             for (xb,yb) in progress_bar(dl):
#                 learn.model(xb)
#                 actns.append((hook.stored).cpu())
#
#         if pool:
#             pool = pool(pool_dim)
#             return pool(torch.cat(actns)).view(len(dl.x),-1)
#         else: return torch.cat(actns).view(len(dl.x),-1)
#
#
#     @staticmethod
#     def comb_similarity(t1: torch.Tensor, t2: torch.Tensor, **kwargs):
#         # https://github.com/pytorch/pytorch/issues/11202
#         "Computes the similarity function between each embedding of `t1` and `t2` matrices."
#         print('Computing similarities...')
#
#         w1 = t1.norm(p=2, dim=1, keepdim=True)
#         w2 = w1 if t2 is t1 else t2.norm(p=2, dim=1, keepdim=True)
#
#         t = torch.mm(t1, t2.t()) / (w1 * w2.t()).clamp(min=1e-8)
#         return torch.tril(t, diagonal=-1)
#
#     def largest_indices(arr, n):
#         "Returns the `n` largest indices from a numpy array `arr`."
#         #https://stackoverflow.com/questions/6910641/how-do-i-get-indices-of-n-maximum-values-in-a-numpy-array
#         flat = arr.flatten()
#         indices = np.argpartition(flat, -n)[-n:]
#         indices = indices[np.argsort(-flat[indices])]
#         return np.unravel_index(indices, arr.shape)
#
#     @classmethod
#     def sort_idxs(cls, similarities):
#         "Sorts `similarities` and return the indexes in pairs ordered by highest similarity."
#         idxs = cls.largest_indices(similarities, len(similarities))
#         idxs = [(idxs[0][i], idxs[1][i]) for i in range(len(idxs[0]))]
#         return [e for l in idxs for e in l]
# File:           ~/anaconda3/envs/project_selfie/lib/python3.7/site-packages/fastai/widgets/image_cleaner.py
# Type:           type
# Subclasses:
